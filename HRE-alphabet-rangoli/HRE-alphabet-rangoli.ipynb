# %% [markdown]
# You are given an integer, . Your task is to print an alphabet rangoli of size . (Rangoli is a form of Indian folk art based on creation of patterns.)
#
# Different sizes of alphabet rangoli are shown below:
#
# #size 3
#
# ----c----
# --c-b-c--
# c-b-a-b-c
# --c-b-c--
# ----c----
#
# #size 5
#
# --------e--------
# ------e-d-e------
# ----e-d-c-d-e----
# --e-d-c-b-c-d-e--
# e-d-c-b-a-b-c-d-e
# --e-d-c-b-c-d-e--
# ----e-d-c-d-e----
# ------e-d-e------
# --------e--------
#
# #size 10
#
# ------------------j------------------
# ----------------j-i-j----------------
# --------------j-i-h-i-j--------------
# ------------j-i-h-g-h-i-j------------
# ----------j-i-h-g-f-g-h-i-j----------
# --------j-i-h-g-f-e-f-g-h-i-j--------
# ------j-i-h-g-f-e-d-e-f-g-h-i-j------
# ----j-i-h-g-f-e-d-c-d-e-f-g-h-i-j----
# --j-i-h-g-f-e-d-c-b-c-d-e-f-g-h-i-j--
# j-i-h-g-f-e-d-c-b-a-b-c-d-e-f-g-h-i-j
# --j-i-h-g-f-e-d-c-b-c-d-e-f-g-h-i-j--
# ----j-i-h-g-f-e-d-c-d-e-f-g-h-i-j----
# ------j-i-h-g-f-e-d-e-f-g-h-i-j------
# --------j-i-h-g-f-e-f-g-h-i-j--------
# ----------j-i-h-g-f-g-h-i-j----------
# ------------j-i-h-g-h-i-j------------
# --------------j-i-h-i-j--------------
# ----------------j-i-j----------------
# ------------------j------------------
# The center of the rangoli has the first alphabet letter a, and the boundary has the  alphabet letter (in alphabetical order).
#
# Function Description
#
# Complete the rangoli function in the editor below.
#
# rangoli has the following parameters:
#
# int size: the size of the rangoli
# Returns
#
# string: a single string made up of each of the lines of the rangoli separated by a newline character (\n)
# Input Format
#
# Only one line of input containing , the size of the rangoli.
#
# Constraints
#
#
# Sample Input
#
# 5
# Sample Output
#
# --------e--------
# ------e-d-e------
# ----e-d-c-d-e----
# --e-d-c-b-c-d-e--
# e-d-c-b-a-b-c-d-e
# --e-d-c-b-c-d-e--
# ----e-d-c-d-e----
# ------e-d-e------
# --------e--------
#
# https://www.hackerrank.com/challenges/alphabet-rangoli/problem?isFullScreen=true

# %%
letters = "abcdefghijklmnopqrstuvwxyz"
n = 5

# Start with the middle line first.

centre_line = "-".join(letters[4:0:-1] + letters[0] + letters[1:5])
print(centre_line)

max_size = len(centre_line)

# Line above and below the centre line, now wrap in loop logic.

print("-".join(letters[4:1:-1] + letters[1] + letters[2:5]))
# Out:
# e-d-c-b-a-b-c-d-e
# e-d-c-b-c-d-e

# %%
# Final submission.

letters = "abcdefghijklmnopqrstuvwxyz"

def print_rangoli(n):

    num_lines_top = n - 1
    centre_line = "-".join(letters[n-1:0:-1] + letters[0] + letters[1:n])
    line_size = len(centre_line)

    # Construct the top (n - 1) lines.
    for i in range(num_lines_top, 0, -1):
        print("-".join(letters[n-1:i:-1] + letters[i] + letters[1+i:n]).center(line_size, "-"))

    # Construct the centre line and the bottom (n-1) lines.
    for i in range(num_lines_top + 1):
        print("-".join(letters[n-1:i:-1] + letters[i] + letters[1+i:n]).center(line_size, "-"))

if __name__ == '__main__':
    n = int(input())
    print_rangoli(n)
# Out:
# ------------------j------------------
# ----------------j-i-j----------------
# --------------j-i-h-i-j--------------
# ------------j-i-h-g-h-i-j------------
# ----------j-i-h-g-f-g-h-i-j----------
# --------j-i-h-g-f-e-f-g-h-i-j--------
# ------j-i-h-g-f-e-d-e-f-g-h-i-j------
# ----j-i-h-g-f-e-d-c-d-e-f-g-h-i-j----
# --j-i-h-g-f-e-d-c-b-c-d-e-f-g-h-i-j--
# j-i-h-g-f-e-d-c-b-a-b-c-d-e-f-g-h-i-j
# --j-i-h-g-f-e-d-c-b-c-d-e-f-g-h-i-j--
# ----j-i-h-g-f-e-d-c-d-e-f-g-h-i-j----
# ------j-i-h-g-f-e-d-e-f-g-h-i-j------
# --------j-i-h-g-f-e-f-g-h-i-j--------
# ----------j-i-h-g-f-g-h-i-j----------
# ------------j-i-h-g-h-i-j------------
# --------------j-i-h-i-j--------------
# ----------------j-i-j----------------
# ------------------j------------------

# %% [markdown]
# Code Review.
#
# * Instead of writing `letters = ` manually, you can use the String module, and after `import string`, `letters = string.ascii_lowercase`.
