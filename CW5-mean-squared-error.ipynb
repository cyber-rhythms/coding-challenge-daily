# %% [markdown]
# Complete the function that
#
# accepts two integer arrays of equal length
# compares the value each member in one array to the corresponding member in the other
# squares the absolute value difference between those two values
# and returns the average of those squared absolute value difference between each member pair.
# Examples
# [1, 2, 3], [4, 5, 6]              -->   9   because (9 + 9 + 9) / 3
# [10, 20, 10, 2], [10, 25, 5, -2]  -->  16.5 because (0 + 25 + 25 + 16) / 4
# [-1, 0], [0, -1]                  -->   1   because (1 + 1) / 2
#
# https://www.codewars.com/kata/51edd51599a189fe7f000015/train/python

# %% [markdown]
# Ideas.
#
# * Should be a simple one liner, particular as arrays are of same length. Will try and remember how to use a generator here.

# %%
# Final submission.

def solution(array_a, array_b):
    mse = 0
    mse += sum(abs(a - b) ** 2 / len(array_a) for a, b in zip(array_a, array_b)) 
    return mse
# Out:
# 9.0

# %% [markdown]
# Code Review.
#
# * And yet simplicity often yields complacency...
# * You do not need an absolute value if you are squaring, incrementing mse is redundant, and no need to perform $n$ divisions...looks like your basics and generator knowledge is rustier than you thought...

# %%
def solution(array_a, array_b):
    return sum(a - b ** 2 / for a, b in zip(array_a, array_b)) / len(array_a)
